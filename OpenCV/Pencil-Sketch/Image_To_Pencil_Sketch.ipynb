# %%
import cv2

# %%
from google.colab.patches import cv2_imshow
image = cv2.imread("/content/cr7.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=768x432 at 0x7F86FFE51790>

# %%
gray_image= cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=768x432 at 0x7F86FFDD5BD0>

# %%
invert_image= 255- gray_image
cv2_imshow(invert_image)
# Out:
# <PIL.Image.Image image mode=L size=768x432 at 0x7F86FFDD5850>

# %%
blurred=cv2.GaussianBlur(invert_image,(21,21),0)

# %%
inverted_blurred = 255-blurred
pencil_sketch = cv2.divide(gray_image,inverted_blurred,scale=256.0)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=768x432 at 0x7F86FFDD8E90>
